# %% [markdown]
# # Materia de inferencia estadistica

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ## Medio poblacional (Parametro)

# %% [markdown]
# El promedio matemático se puede representar como $\mu$
#
# Es la media de todos los datos , osea la poblacion de estudio

# %% [markdown]
# ## Media Muestral

# %% [markdown]
# Las medias muestras o media muestral son el promedio de un subconjunto de datos de una población (una muestra) de n números ,
# representada por $\bar{x}$

# %% [markdown]
# ## Codigo para conseguir las medias muestrales

# %%
import numpy as np
import pandas as pd

#1.- Crear una variable para guardas la columna de la tabla

poblacion = pd.reac_"aca se escribe el tipo de archivo".(tabla["nombre de la comuna"])


#2.- Se crea un arreglo para guardar las medias muestrales

muestras = []
'''
3.- Se crea un ciclo para ir creando las medias muestrales
    Las vueltas del cilo correponderan a la cantidad de medias muestrales que quieras
    Dentro del ciclo se creara una variable que guardara el calculo de la media muestral
    Por ultimo se agrega al arreglo

'''

for i in range(n = cantidad de medias muestrales) :

  '''
  la funcion lleva tres partes, la primera es la poblacion
  la segunda es la cantidad de datos que quiere que tenda la media muestral
  la tercera es impedir que se reemplazen datos
  '''
  muestra = np.random.choice(tabla["nombre columna"], size = 5 , replace = False)
  media_muestral = np.mean(muestra)
  muestras.append(media_muestral) #Con esta linea agregamos la variable a al arreglo

  #En caso de querer mostrar los resultados

  print(f"Promedio muestra ({i+1} = {media_muestral:.2f})")

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# La imagen muestra que si si la cantidad de muestras aumenta, el promedio de la muestra se pareceran mas entre si

# %% [markdown]
# ## Error estandar (Medidor de incertidumbre)

# %% [markdown]
# Representacion de la variabilidad de una estadistica de una muestra
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# Donde $\sigma$ es la desviación estándar y $n$ es la cantidad de datos de media muestral

# %% [markdown]
# Si quieres calcular el error estandar a continuacion tienes un ejemplo de codigo

# %%
import numpy as np

error_estandar = np.std("datos") / np.sqrt(len("datos"))

'''
1.-Para conseguir la desviacion estandar usamos "np.std"
se puede utilizar para una varibale que ya guarde los datos o
sacarlo desde la misma devision ej :

datos = tabla["datos_de_la_tabla"]

desviacion_estandar = datos.std()

si usamos esa desviacion estandar es tambien una opcion, es una tema de comodidad

2.-Para sacar la raiz cuadrada usamos "np.sqrt" , es la forma mas facil de obtener reices
cuadradas, dentro de la funcion ingresamos el numero, en esta caso es el el largo del conjunto de datos.
Osea que en una tabla tenemos 4 registros su tamaño seria de 4. como ejemplo

cantidad_datos = np.len("tabla[datos[]")

error_estandar = np.std("datos") / np.sqrt(cantidad_datos)

3.- Por ultimo dividir la deviacion estandar por la raiz cuadrada de la cantidad de datos

'''

# %% [markdown]
# # Intervalos de confianza

# %% [markdown]
# Para saber que tan confiable es una media muestral en relaciona a la media poblacional usamos lo que son los intervalos de confianza.
#
# Los intervalos de confianza son un rango de valores calculado a partir de los datos muestrales. Se espera que este rango contenga el verdadero valor del parámetro poblacional  con un determinado Nivel de Confianza.
# Estos intervalos se expresan como [a,b] donde a es el límite inferior y b es el límite superior
#
# Para saber que valores poner usamos lo que es el nivel de confianza

# %% [markdown]
# # Nivel de confianza

# %% [markdown]
# El nivel de confianza es la probabilidad con la que se espera que un intervalo de confianza  I contenga el verdadero valor del parametro T (media poblacional)
# La expresion es la siguiente.

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# Donde:
# $P$ = probabilidad
# $T$ = Parámetro verdadero (Media poblacional)
# $E$ = Pertenece a
# $I$ = Es tu Intervalo de confianza, es decir, el límite inferior y superior que calculaste con tus datos (por ejemplo, el rango "entre 18 y 22 años").
# $1 - \alpha$: Todo esto junto es el Nivel de confianza. Es tu grado de certeza, generalmente expresado en porcentaje (90%, 95%, 99%).
#
# a (alpha) = (Alfa): Es el Nivel de significancia o de error. Representa el riesgo que estás dispuesto a asumir. Es la probabilidad de que la verdadera media (T) no esté dentro de tu intervalo (I).
#
# entonces si escoges 90 de vería
#
# alpha - 1 = 90 ->  eso vendría siendo el nivel de confianza. un 90
#
# pero el resultado de eso es el riesgo , que es el  100- el nivel de confianza que escogiste

# %% [markdown]
# ## Componentes de un intervalo de confianza :
#
# 1.- Estimador muestral :  Es la media muestral o la proporcion muestral
#
# 2.-Nivel de confianza : Generalmente 90%, 95% y 99%
#
# 3.- Magen de error : determinado por la amplitud del intervalo
#
#
#
# Para que un intervalo de confianza sea válido, se asume que:
#
# La muestra es representativa de la población.
# Las observaciones son independientes.
# El tamaño de la muestra es suficiente.

# %% [markdown]
# ## Intervalos de confianza para la media (obtener el resultado de [a,b])

# %% [markdown]
# Un intervalo de confianza para la media es un rango en el cual se considera altamente probable que se encuentre la media poblacional $\mu$ , se obtiene con una de las siguientes maneras :

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# Con N garnde se refiere a que es mayor o igual a 30 (>=30) y $\sigma$
# es la desviacion estandar

# %% [markdown]
# ## Desglose de la formula de los intervalos de la media
#
# $\bar{x}$ = vendría siendo la media muestral
# $Z_{\alpha/2}$ = es el riesgo (resultado del intervalo de confianza menos 1 partido en dos)
# $\frac{\sigma}{\sqrt{n}}$ = es el error estándar (la desviación estándar partido en la raíz cuadrada de la cantidad de datos de la muestra)
#
# Tomar en cuenta de que se ingresan los mimso valores en ambos limites , solo camba en lo la operacion entre la media muestral y el resto de la formula (margen de error)

# %% [markdown]
# Codigo con mutiples opciones de desarrollo

# %%
# Librerías
import numpy as np
import pandas as pd
import scipy.stats as st

'''
Criterios:
- Desviación estándar poblacional (sigma) ES CONOCIDA o muestra grande (Mayor a 30): Distribución Normal (Z).
- Desviación estándar poblacional ES DESCONOCIDA: t-Student.

Cosas que necesitamos calcular o definir para este caso (Normal):
- Tamaño de la muestra (n)
- Media muestral (x̄)
- Desviación estándar poblacional (sigma) -> ¡Este es un dato dado!
- Error estándar (sigma / √n)
'''

# 1. Lectura de la tabla
tabla = pd.read_excel('tabla.xlsx')

# PASO OPCIONAL: Guardar la columna en una variable
muestra = tabla['Nombre_Columna']

# 2. Definición de la desviación estándar poblacional conocida (sigma)
desv_poblacional = 15.0  # Dato ficticio de ejemplo

# 3. Cálculos de Estadísticos y Error Estándar

# --- OPCIÓN 1: Cálculo concatenando métodos directos de la tabla ---
# Ideal si quieres ahorrar líneas de código
error_estandar = desv_poblacional / np.sqrt(len(tabla['Nombre_Columna']))
media_muestral = tabla['Nombre_Columna'].mean()

#Opcion 2: Cálculo guardando en variables paso a paso ---
# Ideal para mantener el orden y legibilidad
tamaño_muestral = len(muestra)
media_muestral = np.mean(muestra) # También sirve muestra.mean()
error_estandar = desv_poblacional / np.sqrt(tamaño_muestral)

# 4. Cálculo de los Intervalos de Confianza

# --- OPCIÓN 1: Ingresando los cálculos directamente en la función ---
intervalos_confianza = st.norm.interval(confidence=0.95, loc=tabla['Nombre_Columna'].mean(), scale=(desv_poblacional / np.sqrt(len(tabla['Nombre_Columna']))))

# --- OPCIÓN 2: Usando las variables limpias ---
intervalos_confianza = st.norm.interval(confidence=0.95, loc=media_muestral, scale=error_estandar)

# Al imprimir tendremos un arreglo con el límite inferior y superior
print(f"Resultado Opción 1 -> Límite inferior: {intervalos_confianza[0]:.2f} , Límite superior: {intervalos_confianza[1]:.2f}")

# %% [markdown]
# Versional lineal con varibales que guardan los calculos en variables

# %%
# Librerías
import numpy as np
import pandas as pd
import scipy.stats as st

'''
Criterios:
- Desviación estándar poblacional (sigma) ES CONOCIDA o muestra grande: Distribución Normal (Z).
- Desviación estándar poblacional ES DESCONOCIDA: t-Student.

Cosas que necesitamos calcular o definir:
- Tamaño de los datos (n)
- Media muestral (x̄)
- Desviación estándar poblacional (sigma) -> Dato dado
- Error estándar (sigma / √n)
'''

# 1. Lectura de la tabla y extracción de la muestra
tabla = pd.read_excel('tabla.xlsx')
muestra = tabla['Nombre_Columna']

# 2. Variables que guardan los datos iniciales
# IMPORTANTE: Aquí debes ingresar el valor real de tu desviación poblacional
desviacion_poblacional_conocida = 15.0

# 3. Estadísticos necesarios
tamaño_muestral = len(muestra)
media_muestral = np.mean(muestra)

# 4. Cálculo del error estándar
error_estandar = desviacion_poblacional_conocida / np.sqrt(tamaño_muestral)

# 5. Cálculo del intervalo de confianza (Distribución Normal)
intervalo_confianza = st.norm.interval(confidence=0.95, loc=media_muestral, scale=error_estandar
)

# 6. Impresión de resultados
# Al imprimir tendremos un arreglo con el límite inferior y superior
print(f"Límite inferior: {intervalo_confianza[0]:.2f} , Límite superior: {intervalo_confianza[1]:.2f}")

# %% [markdown]
# #Obtener la media los intervalos de confianza para T-student

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# $\bar{x}$  (Media muestral ) : es el promedio que calculas usando unicamente los datos de tu muestra
#
# $t_{\frac{\alpha}{2}, n-1}$ (Valor crítico t): Es el multiplicador que sacas de una tabla estadística
#
# (la distribución t de Student). Sus componentes son:
#
# *   $\frac{\alpha}{2}$: Es tu margen de error total ($\alpha$) dividido en dos, para repartirlo en ambas colas de la campana, tal como vimos antes.
#
#
# *   $n-1$ (Grados de libertad): Es tu tamaño de muestra menos uno. Esto le indica a la tabla qué tan pequeña es tu muestra para ajustar el margen de seguridad.
#
# $\frac{\sigma}{\sqrt{n}}$ = es el error estándar (la desviación estándar partido en la raíz cuadrada de la cantidad de datos de la muestra)

# %% [markdown]
# # Para que se usa T-Student ?

# %% [markdown]
# En una situacion ideal, tú conocerías la desviación estándar poblacional ($\sigma$). Pero en la vida real, si estás tomando una muestra para adivinar el promedio de una población, es ilógico pensar que vas a conocer la dispersión de esa misma población. ¡Si no conoces el promedio, menos vas a conocer su dispersión!Como no conoces $\sigma$, tienes que estimarla usando la desviación de tu muestra ($s$).El problema es que al estimar, estás agregando más incertidumbre. Ya no solo estás adivinando la media ($\mu$), sino que también estás adivinando la dispersión ($\sigma$). Para compensar esta "doble ignorancia" (especialmente si tu muestra es pequeña, menos de 30 datos), la estadística te obliga a usar la distribución $t$.

# %% [markdown]
# # Codigo T-Student

# %% [markdown]
# Version de codigo con multiples opciones de flujo de trabajo (despues de esta esta la version con una sola ruta)

# %%
import numpy as np
import pandas as pd
import scipy.stats as st

'''
Cosas que necesitamos calcular

-Tamaño de los datos
-Media muestral
-Desviacion estandar
-Error estandar

'''

#1.-Lectura de los datos muestrales desde el archivo (normalmente excel)

tabla = pd.read_excel('tabla.xlsx')

tabla.head() #Esta liena te seriva para ver algunas filas de la tabla (primeras 6)
#Puede ser util para ver el nombre de las tablas

#PASO OPCIONAL
#Podemos guardar nuestra muestra en una variable, esto sirve para que tener mejor orden

muestra = tabla['Nombre_Columna']

#2.- Extraccion de la media muestral

#Opcion 1 :
media_muestral = tabla['Nombre_Columna'].mean() #con .mean() sacamos la media o promedio

#Opcion 2 (creacion de una variable que guarda la media) :

media_muestral = muestra.mean()

#3.- Desviacion estandar

#Opcion 1:
desviacion_estandar = tabla['Nombre_Columna'].std(ddof=1)

#Opcion 2 (Uso de la variable que guarda la muestra)

desviacion_estandar = muestra.std(ddof=1)

#LO QUE ENTRE PARENTESIS "ddof=1" ES PARA INDICAR QUE SE ESTA TRABAjANDO A NIVEL MUESTRAL

#4.- Calculo del error estandar
#opcion 1 :
error_estandar = desviacion_estandar / np.sqrt(len(tabla["Nombre_Columna"]))


#Opcion 2 (usando variable que guarda la muestra):

tamaño_datos = len(muestra)
error_estandar = desviacion_estandar / np.sqrt(tamaño_datos)

#5.-Calculmas los intervalos de confianza

#Opcion 1 :
intervalos_confianza = st.t.interval(confidence = 0.95, df=len(tabla["Nombre_Columna"])-1, loc=tabla['Nombre_Columna'].mean() , scale=error_estandar)

#Opcion 2 (usando variables que guardan los calculos):

tamaño_datos = len(muestra)

intervalos_confianza = st.t.interval(confidence = 0.95, df=tamaño_datos-1, loc=media_muestral, scale=error_estandar)

#Al imprimir tendremos un arreglo con el limite inferior y superior
print(f"{intervalos_confianza[0]:.2f} , {intervalos_confianza[1]:.2f}")

# %% [markdown]
# Versional lineal con varibales que guardan los calculos en variables

# %%
import numpy as np
import pandas as pd
import scipy.stats as st

'''
Cosas que necesitamos calcular

-Tamaño de los datos
-Media muestral
-Desviacion estandar
-Error estandar

'''

#1.-Lectura de tabla
tabla = pd.read_excel('tabla.xlsx')

#2.-Primero 5 filas de la tabla
tabla.head()

#3.-Extraccion de los datos (columna de una tabla)
muestra = tabla['Nombre_Columna']

#4.-Calculo de media muestral
media_muestral = muestra.mean()

#5.-Caclulo de la desviacion estandar
desviacion_estandar = muestra.std(ddof=1)

#5.-Cacluclo del error estandar sacando la cantidad de datos

tamaño_datos = len(muestra)
error_estandar = desviacion_estandar / np.sqrt(tamaño_datos)

#6.-Se extrae la cantidad de datos (numero de filas de la columna)
tamaño_datos = len(muestra)

#7.-Calculos de los intervalos de confianza
intervalos_confianza = st.t.interval(confidence = 0.95, df=tamaño_datos-1, loc=media_muestral, scale=error_estandar)

#Se imprime los limites inferiores y superiores
print(f"{intervalos_confianza[0]:.2f} , {intervalos_confianza[1]:.2f}")

# %% [markdown]
# #Intervalos de confianza para la proporcion

# %% [markdown]
# ## Que es la proporcion ?

# %% [markdown]
# Una proporción es la fracción, parte o porcentaje de un grupo total que cumple con una característica específica.Mientras que la media poblacional ($\mu$) te responde a la pregunta "¿Cuánto es el promedio?", la proporción ($p$) te responde a la pregunta "¿Cuántos (o qué porcentaje) son de este tipo?".

# %% [markdown]
# ##Que vendria siendo entonces intervalos de confianza para la proporcion ?

# %% [markdown]
# Los intervalos de confianza para la proporción son un rango de porcentajes que dice que la condición que encontré en mi muestra, se va a repetir en un cierto pedazo (porcentaje) de mi población total.

# %% [markdown]
# # Formula para sacar los intervalos de confianza para la proporcion

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ## Desglose de la formula
#
# La fórmula se divide en un límite inferior (resta) y un límite superior (suma). Consta de las siguientes partes:
#
# * **$\hat{p}$ (Proporción Muestral):** Es el porcentaje exacto de "éxitos" (casos que cumplen la condición) que encontramos dentro de nuestra muestra. Es el centro exacto de nuestro intervalo.
#   * **¿Cómo se calcula?** Se divide la cantidad de éxitos ($x$) por el tamaño total de la muestra ($n$). Su fórmula es: $\hat{p} = \frac{x}{n}$
#
# * **$1 - \hat{p}$ (Proporción de Fracasos):** Es simplemente el porcentaje restante de tu muestra. Si tu proporción de éxito fue del 30% ($0.30$), tu proporción de fracaso es del 70% ($0.70$).
#
# * **$n$ (Tamaño de la Muestra):** Es la cantidad total de datos, personas o elementos que evaluaste en tu grupo de estudio.
#
# * **$z_{\frac{\alpha}{2}}$ (Valor Crítico Z):** Es el multiplicador estadístico que define nuestro Nivel de Confianza (ej. 95%). El subíndice $\frac{\alpha}{2}$ indica que nuestro riesgo de error total ($\alpha$) se ha partido en dos partes iguales, colocando una mitad en la cola izquierda y otra en la cola derecha de la distribución normal.
#
# * **$\sqrt{\frac{\hat{p} \cdot (1 - \hat{p})}{n}}$ (Error Estándar de la Proporción):** Toda esta raíz cuadrada es el equivalente a la desviación estándar, pero calculada específicamente para porcentajes. Nos dice qué tanto varían los datos basándose directamente en la misma proporción.
#
# * **El bloque $z_{\frac{\alpha}{2}} \cdot \sqrt{\frac{\hat{p} \cdot (1 - \hat{p})}{n}}$ (Margen de Error):** Es el resultado final que le vamos a restar y sumar a nuestro $\hat{p}$ central para construir los límites del intervalo.
#
# ---

# %% [markdown]
# ## 2. Requisitos de Aplicación (Aproximación a la Normal)
#
#
# Esta fórmula matemática funciona gracias a un "truco" estadístico: asume que, si tenemos suficientes datos, una distribución de proporciones (que originalmente es Binomial) adoptará la forma perfecta de una Campana de Gauss (Distribución Normal).
#
# Para que esta suposición matemática sea válida y nuestro intervalo no entregue resultados mentirosos o sesgados, se **deben cumplir estrictamente estas dos reglas** antes de aplicar la fórmula:
#
# 1. **$n \cdot \hat{p} \ge 10$** *(El número de éxitos observados en tu muestra debe ser mayor o igual a 10).*
# 2. **$n \cdot (1 - \hat{p}) \ge 10$** *(El número de fracasos observados en tu muestra debe ser mayor o igual a 10).*
#
# **¿Qué pasa si no se cumplen?** Significa que tu muestra es demasiado pequeña o tu característica es demasiado rara. El intervalo pierde fiabilidad y tendrías que usar métodos estadísticos más avanzados (métodos exactos) en lugar de esta fórmula general.

# %% [markdown]
# #Codigo para sacar los intervalos para la proporcion

# %%
import numpy as np
import pandas as pd
import scipy.stats as st

'''
Datos y cálculos necesarios para el Intervalo de Proporción:
- Tamaño Muestral (n)
- Contabilizar éxitos (x)
- Proporción muestral (p_hat)
- Nivel de significancia (alpha) y Valor crítico Z
- Error estándar (ee)
'''

# 1.- Lectura de la muestra (ejemplo con Excel)
df = pd.read_excel("Nombre_del_archivo.xlsx")

# 2.- Extracción de columna de la tabla y la guardamos en una variable
muestra = df["Nombre_columna"]

# 3.- Contabilizamos el tamaño de los datos (n)
# CORRECCIÓN: Es len(), no np.len()
n = len(muestra)

# 4.- Extraemos los "éxitos" (filtramos los datos que cumplen la condición)
exitos = muestra[muestra == "atributo_de_la_columna"]

# 5.- Contabilizamos los éxitos (x)
num_exitos = len(exitos)

# 6.- Cálculo de proporción muestral (p_hat)
proporcion_muestral = num_exitos / n

# 7.- Sacar valor crítico Z
# Si queremos un 95% de confianza, nuestro alpha (margen de error) es 0.05
alpha = 0.05

z = st.norm.ppf(1 - alpha/2)

# 8.- Calculamos el error estándar
# Aplicamos la fórmula de la raíz cuadrada: sqrt( (p * (1-p)) / n )
ee = np.sqrt(proporcion_muestral * (1 - proporcion_muestral) / n)

# 9.- Cálculo de los intervalos de confianza
limite_inferior = proporcion_muestral - (z * ee)
limite_superior = proporcion_muestral + (z * ee)

ic = (limite_inferior, limite_superior)

# 10.- Imprimir los resultados (El paso que faltaba)
print(f"Límite inferior: {ic[0] * 100:.2f}%")
print(f"Límite superior: {ic[1] * 100:.2f}%")
print(f"Conclusión: Estamos un {(1-alpha)*100:.0f}% seguros de que la proporción real de la población está entre {ic[0] * 100:.2f}% y {ic[1] * 100:.2f}%.")
# Out:
#   File "/tmp/ipykernel_3831/3545798428.py", line 6
#     df = pd.read_....("Nombre del archivo")
#                  ^
# SyntaxError: invalid syntax

# %% [markdown]
# # Crear un histograma para la media

# %%
import matplotlib.pyplot as plt

# 1. Crear el histograma
plt.hist(data_tiempo_espera['tiempo_espera_min'], bins=10, color='skyblue', edgecolor='black')

# 2. Añadir la línea de la media (para que se vea dónde caen esos 47 min)
plt.axvline(media_tiempo, color='red', linestyle='dashed', linewidth=2, label=f'Media: {media_tiempo:.2f}')

# 3. Personalizar etiquetas
plt.title('Distribución de Tiempos de Espera')
plt.xlabel('Minutos')
plt.ylabel('Cantidad de Pacientes')
plt.legend()

# 4. Mostrar el gráfico
plt.show()
